# %% [markdown]
# # Steering
# The plot shows both directions. Inspect `results/coherence.csv` before claiming that control preserves fluent generation.

# %%
from interp.plot_results import steering
steering('results/steering.csv', 'figures/steering.png')
