# %% [markdown]
# # Activation patching
# The critical layer is the row with the largest mean normalized disruption score. The notebook contains no analysis logic.

# %%
from interp.plot_results import patching
patching('results/patching.csv', 'figures/patching_heatmap.png')
