# %% [markdown]
# # Logit lens
# This notebook only visualizes the saved experiment CSV. Run `python -m interp.logit_lens` first.

# %%
from interp.plot_results import logit_lens
logit_lens('results/logit_lens.csv', 'figures/logit_lens.png')
